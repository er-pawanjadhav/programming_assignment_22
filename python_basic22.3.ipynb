# %%
a = ["Harry", "Newt", "Luna", "Cho"]
def society_name(a):
    b = []
    for i in a:
        b.append(i[0])
    b = sorted(b)
    s=''
    for i in b:
        s = s+i
    return s
print(society_name(a))
# Out:
# CHLN
