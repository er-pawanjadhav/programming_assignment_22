# %%
def list_op(a,b,c):
    d = []
    for i in range(a,b+1):
        if i%c==0:
            d.append(i)
    return d
a = int(input("enter starting no : "))
b = int(input("enter ending no : "))
c = int(input("enter divisor no : "))

print(list_op(a,b,c))
# Out:
# enter starting no : 1
# enter ending no : 10
# enter divisor no : 3
# [3, 6, 9]
