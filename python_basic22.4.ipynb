# %%
def is_isogram(a):
    bol = True
    for i in a:
        if a.count(i)!=1:
            bol = False
    return bol

a = input("enter a string : ")
a = a.lower()

print(is_isogram(a))
# Out:
# enter a string : PasSword
# False
