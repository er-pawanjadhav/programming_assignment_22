# %%
def is_in_order(a):
    if len(a)>0:
        b = sorted(a)
        c=''
        c=c.join(b)
        return a==c
    else:
        return "enter valid string "
a = input("enter string : ")
print(is_in_order(a))
# Out:
# enter string : 12445
# True
